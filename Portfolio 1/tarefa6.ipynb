# %% [markdown]
# ## Tarefa 6 - Soma dos Quadrados
#
# |Linguagem|IDE|Processador|RAM|
# |--|--|--|--|
# |Python|VSCode|Intel(R) Celeron(R) CPU  J3060  1.60 GHz|4 GB (utilizável: 3,84 GB)|
#
# ### Os dois algoritmos devolvem o mesmo número se receberem o mesmo valor de entrada n?
# R: Sim
#
#
#
# ### Qual dos dois algoritmos é mais eficiente?
# R: O algoritmo `soma_quadrados_B()` porque ele demanda menos esforço computacional para retornar o mesmo valor de saída do algoritmo `soma_quadrados_A()`.
#
# #### Gráfico
# ##### Sendo: 10000000 <=  n  > 55000000
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Código-fonte

# %%
import time
import matplotlib.pyplot as plt # type: ignore

def soma_quadrados_A(n):
    x = 0
    for i in range(n + 1):
        x += i * i
    return x


def soma_quadrados_B(n):
    return (n * (n + 1) * ( 2*n + 1)) / 6


def calcular_tempo(funcao, n):
    inicio = time.perf_counter()
    funcao(n)
    fim = time.perf_counter()
    return fim - inicio


tempos_A = []
tempos_B = []
nums = []

qtde = int(input('Digite a quantidade de valores: '))

for i in range(qtde):
    nums.append(int(input(f'Digite o valor {i+1}: ')))

for i in range(len(nums)):
    tempos_A.append(calcular_tempo(soma_quadrados_A, nums[i]))
    tempos_B.append(calcular_tempo(soma_quadrados_B, nums[i]))

plt.plot(nums, tempos_A, color='red', linestyle='--', marker='o', label='soma_quadrados_A')
plt.plot(nums, tempos_B, color='blue', linestyle='--', marker='o', label='soma_quadrados_B')
plt.xlabel('n')
plt.ylabel('Tempo de Execução (s)')
plt.title('soma_quadrados_A x soma_quadrados_B')
plt.legend()
plt.show()

# %%
soma1 = soma_quadrados_A(10)
soma2 = soma_quadrados_B(10)
print(soma1, soma2)

#para valores aleatórios
# import random
# qtde = int(input('Digite a quantidade de valores: '))
# for i in range(qtde):
#     n = random.randint(1000000, 10000000)
#     tempos_A.append(calcular_tempo(soma_quadrados_A, n))
#     tempos_B.append(calcular_tempo(soma_quadrados_B, n))
#     nums.append(n)
# nums.clear()
# Out:
# 285 385.0
